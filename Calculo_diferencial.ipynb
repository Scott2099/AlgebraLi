# %% [markdown]
# <a href="https://colab.research.google.com/github/Scott2099/AlgebraLi/blob/main/Calculo_diferencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Grafica de funciones
#Calculo diferencial
from sympy.solvers import solve
from sympy import Symbol
import matplotlib.pyplot as plt
import numpy as np
x= np.linspace(-4,4,100)
y= x**2-2
plt.plot(x, y, '-r', label= 'y=x**2-2')
#plt.title('Graph of y=2x+1')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper left')
plt.grid()
plt.show()
x= symbol
